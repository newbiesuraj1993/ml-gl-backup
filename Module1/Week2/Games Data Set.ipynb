# %%
import pandas as pd
import seaborn as sns
sns.set_color_codes=True
# %matplotlib inline

# %%
games=pd.read_csv('./games-data/games.csv')

# %%
games=games.dropna()

# %%
games.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %%
games['type'].value_counts()
# Out:
# boardgame             70777
# boardgameexpansion    10491
# Name: type, dtype: int64

# %%
games[games['yearpublished']>2013]
# Out:
#            id                type  \
# 11     164153           boardgame
# 17     150376           boardgame
# 37     157354           boardgame
# 39     132531           boardgame
# 50     155426           boardgame
# 52     147020           boardgame
# 57     161970           boardgame
# 63     146652           boardgame
# 66     148228           boardgame
# 69     154203           boardgame
# 90     163412           boardgame
# 101    148949           boardgame
# 115    171623           boardgame
# 122    157969           boardgame
# 127    159675           boardgame
# 132    147949           boardgame
# 157    155068           boardgame
# 182    146886           boardgame
# 190    148575           boardgame
# 199    160499           boardgame
# 215    158275           boardgame
# 230    162082           boardgame
# 233    150658           boardgame
# 242     82222           boardgame
# 245    146791           boardgame
# 260    109276           boardgame
# ...

# %%
games[games['total_comments']==games['total_comments'].max()]
# Out:
#       id       type   name  yearpublished  minplayers  maxplayers  \
# 165   13  boardgame  Catan         1995.0         3.0         4.0
# 1965  13  boardgame  Catan         1995.0         3.0         4.0
#
#       playingtime  minplaytime  maxplaytime  minage  users_rated  \
# 165          90.0         90.0         90.0    10.0        53680
# 1965         90.0         90.0         90.0    10.0        53680
#
#       average_rating  bayes_average_rating  total_owners  total_traders  \
# 165          7.34303               7.21171         73188           1071
# 1965         7.34303               7.21171         73188           1071
#
#       total_wanters  total_wishers  total_comments  total_weights  \
# 165             391           3201           11798           5996
# 1965            391           3201           11798           5996
#
#       average_weight
# 165           2.3712
# 1965          2.3712

# %%
games.groupby('type')['minage'].mean()
# Out:
# type
# boardgame             6.723300
# boardgameexpansion    8.733295
# Name: minage, dtype: float64

# %%
games['id'].nunique()
# Out:
# 79419

# %%
myl=[1,2,3,4]
mynewlist=[i+1 for i in myl]

# %%
mynewlist
# Out:
# [2, 3, 4, 5]

# %%
i=[i for i in range(0,20) if i%3==0]

# %%
i
# Out:
# [0, 3, 6, 9, 12, 15, 18]
